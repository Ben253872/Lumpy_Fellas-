# %% [markdown]
# # 3. Benchmark models
#
# This notebook runs the baseline methods extracted from the original exploration: naive, seasonal naive, SMA (3 and 6), Croston, SBA, and TSB. Results are written as CSV files.

# %%
from pathlib import Path
import subprocess

root = Path.cwd().resolve()
if not (root / 'src').exists():
    root = root.parent
subprocess.run(['python', 'src/run_benchmarks.py'], cwd=root, check=True)

# %%
import pandas as pd
metrics = pd.read_csv(root / 'results/tables/benchmark_metrics.csv')
metrics.sort_values(['demand_type', 'wmape_percent'])
