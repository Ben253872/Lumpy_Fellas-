# %% [markdown]
# # 4. Advanced models
#
# The original notebook's advanced experiments are in `src/models/advanced.py`: XGBoost, LightGBM, Random Forest, and a two-stage LightGBM hurdle model for lumpy demand. Install `xgboost` and `lightgbm` before running those models.

# %%
from pathlib import Path
import sys

root = Path.cwd().resolve()
if not (root / 'src').exists():
    root = root.parent
sys.path.insert(0, str(root / 'src'))
from models.advanced import engineer_time_features, tree_forecast, lumpy_hurdle_forecast

# %% [markdown]
# ## Output convention
#
# Save forecasts to `results/tables/advanced_forecasts.csv`, metrics to `results/tables/advanced_metrics.csv`, and feature importance to `results/tables/feature_importance.csv`. Keep model charts in `results/figures/`.
