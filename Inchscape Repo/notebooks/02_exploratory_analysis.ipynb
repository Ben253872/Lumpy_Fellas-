# %% [markdown]
# # 2. Exploratory analysis
#
# Create labelled figures and CSV analysis tables from the four processed demand segments.

# %%
from pathlib import Path
import subprocess

root = Path.cwd().resolve()
if not (root / 'src').exists():
    root = root.parent
subprocess.run(['python', 'src/run_eda.py'], cwd=root, check=True)

# %%
import pandas as pd
pd.read_csv(root / 'results/tables/demand_type_summary.csv')
